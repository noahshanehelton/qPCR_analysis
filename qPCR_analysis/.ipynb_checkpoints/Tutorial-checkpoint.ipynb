# %% [markdown]
# ***Install Tutorial***

# %%
import Data_processing#from qPCR_analysis import Plotting
import Plotting
import numpy as np 
import pandas as pd 
import scipy 
import matplotlib.pyplot as plt

# %% [markdown]
# ***Dataset Overview***
#
# The primary goal of this analysis is to see how the gene ATF4 is expressed during acute arsenite stress. The approach will be to monitor mRNA levels of ATF4 in the cell and in polysomes in stressed and unstressed conditions. To do this, we will use this qPCR analysis package which can calculate primer efficiency of qPCR primers, the gene expression ration compared to GAPDH of a gene of interest, and the percent mRNA in a fraction of a polysome. This dataset will go over the main functionalities of the qPCR analysis package which include primer effieciency calculation, which inputs a dilution series of Ct values and calculates a slope and primer efficiency. Using this primer efficiency calculation, you can then perform the pfaffl method of qPCR analysis, which takes into account a gene of interest and a control gene followed by a gene expression ration calculation. Finally, we will use previously established methods to quantify the percent mRNA in polysome fractions.

# %% [markdown]
# ***Primer Efficiency tutorial***

# %% [markdown]
# This tutorial will show how to use the functions to calculate primer efficiency of a dilution series.
# In order to calculate primer efficiency, you will need csv file with the following headings:
#
# 'Gene'
# 'Dilution'
# 'Ct1'
# 'Ct2'
# 'Ct3'
#
# Import your CSV using the function *import_and_tidy_data* using the filepath your csv file
#
#
# The overall pipeline will be to use the *primer_efficiency* function. This will generate a pandas dataframe with your gene, slope, intercept, error, R_value, P_value, and Primer effiency.

# %%
#Import dataset and check it 
dilution_data = Data_processing.import_and_tidy_data('biological_data/ATF4_primer_Efficiency.csv')
print(dilution_data)
# Out:
#    Gene  Dilution     Ct1     Ct2     Ct3   Ct_value       SEM
# 0  ATF4     1.000  18.425  18.462  18.542  18.476333  0.034527
# 1  ATF4     0.200  20.744  20.809  20.752  20.768333  0.020464
# 2  ATF4     0.040  23.265  23.354  23.279  23.299333  0.027630
# 3  ATF4     0.008  25.760  25.850  25.666  25.758667  0.053120

# %%
#Calculate primer efficiency 
primer_efficiency = Data_processing.primer_efficiency(dilution_data, 'ATF4')
print(primer_efficiency)
# Out:
#    Gene     Slope  Intercept     Error         R   p_value  Primer Efficiency
# 0  ATF4 -3.487703  18.418967  0.049199 -0.999801  0.000199              93.52

# %%
#Plot primer efficiency:
ATF4 = Plotting.plot_efficiency_graph(dilution_data, primer_efficiency, 'ATF4')

# %%
#save plot: 
Plotting.save_plot(ATF4,Plotting.get_save_path())
# Out:
# Enter the path to save the plot or press enter to use the default (/default/path/plot.png):  test1.png
# Plot saved to test1.png

# %% [markdown]
# ***Differential gene expression analysis***
#
# The first goal will be to analyze if stress induces ATF4 mRNA increases. To do this, we will analyze RT-qPCR data of ATF4 and get the gene expression ratio as normalized to gapdh. We will calculate differential expression and plot as a bar graph

# %%
# import data
Gene_expression_Data = Data_processing.import_and_tidy_data('biological_data/Gene_expression_analysis.csv')
print(Gene_expression_Data)
# Out:
#      Gene  Condition  Replicate     Ct1     Ct2     Ct3   Ct_value       SEM
# 0    ATF4    Treated          1  18.966  18.756  18.653  18.791667  0.092098
# 1    ATF4    Treated          2  17.812  18.380  18.169  18.120333  0.165763
# 2    ATF4    Treated          3  17.929  17.931  17.933  17.931000  0.001155
# 3    ATF4  Untreated          1  18.425  18.347  18.329  18.367000  0.029462
# 4    ATF4  Untreated          2  18.343  18.365  18.249  18.319000  0.035572
# 5    ATF4  Untreated          3  17.721  17.760  17.740  17.740333  0.011260
# 6   GAPDH    Treated          1  14.873  14.898  14.900  14.890333  0.008686
# 7   GAPDH    Treated          2  13.941  13.951  13.952  13.948000  0.003512
# 8   GAPDH    Treated          3  14.328  14.324  14.252  14.301333  0.024694
# 9   GAPDH  Untreated          1  14.829  14.836  14.842  14.835667  0.003756
# 10  GAPDH  Untreated          2  13.953  13.967  13.957  13.959000  0.004163
# ...

# %%
#Process data
Gene_expression_df = Data_processing.pfaffl('ATF4', 'GAPDH', 'Treated', 'Untreated',93.52, 95.0, Gene_expression_Data)
print(Gene_expression_df)
# Out:
#    Gene  Condition  Gene Expression Ratio 1  Gene Expression Ratio 2  \
# 0  ATF4  Untreated               176.784433               212.943642
# 1  ATF4    Treated               138.527607               241.011168
#
#    Gene Expression Ratio 3  Average GER    SEM GER
# 0               148.422253   179.383443  18.670998
# 1               167.325717   182.288164  30.515713

# %%
Differential_expression = Plotting.plot_gene_expression_ratio(Gene_expression_df, 'ATF4')
Plotting.save_plot(Differential_expression,Plotting.get_save_path())
# Out:
# Enter the path to save the plot or press enter to use the default (/default/path/plot.png):  Test2.png
# Plot saved to Test2.png

# %% [markdown]
# ***Analysis of mRNA translation status through polysome profiling and RT-qPCR analysis***
#
# Polysome profiling is a powerful technique that can identify the relative amount of translation. This technique takes advantage of sucrose gradient density ultracentrifugation followed by measuring absorbance at 254 nm during fractionation to visualize ribosomal subunits and ribosomes. You can isolate free RNA, light polysomes, and heavy polysomes and extract RNA from each fraction. RT-qPCR can then be used to elicit the relative translation status of your favorite gene.
#
# This tutorial will analyze the stress-induced gene mRNA, *ATF4*'s translation status during unstressed conditions and during acute sodium arsenite stress. This will require the following steps:
#
# 1. Import .csv file with the following headers:
# 2. Perform the polysome profiling analysis by inputting your data frame, gene of interest name, condition, and # of replicates
# 3. Plot data with plot_gene_fractions
# 4. Save data with save_plot and get_save_path

# %%
#Import polysome profiling data method dataset 
polysome_profile_data = Data_processing.import_and_tidy_data('biological_data/ATF4_polysome_profile.csv')
polysome_profile_data
# Out:
#     Gene  Fraction  Condition        Ct1        Ct2        Ct3   Ct_value  \
# 0   ATF4         1    Treated  25.073000  25.510333  26.735000  25.772778
# 1   ATF4         2    Treated  26.041500  24.091667  25.970333  25.367833
# 2   ATF4         3    Treated  21.686000  22.182333  23.615333  22.494556
# 3   ATF4         4    Treated  22.102667  26.455333  23.974000  24.177333
# 4   ATF4         5    Treated  26.433333  23.526667  25.954667  25.304889
# 5   ATF4         6    Treated  22.313667  22.200000  24.367667  22.960444
# 6   ATF4         7    Treated  25.112667  21.378333  23.585667  23.358889
# 7   ATF4         8    Treated  19.915667  21.352333  25.573000  22.280333
# 8   ATF4         9    Treated  18.936333  20.757333  23.753000  21.148889
# 9   ATF4        10    Treated  19.739333  19.678667  21.653333  20.357111
# 10  ATF4        11    Treated  18.791667  22.467333  22.261333  21.173444
# 11  ATF4        12    Treated  18.707333  19.880667  21.518333  20.035444
# ...

# %%
#polysome_test = Data_processing.import_and_tidy_data('data/polysome_profile_testdata.csv')
ATF4_polysome_untreated = Data_processing.polysome_profiling_analysis(polysome_profile_data, 'ATF4','Untreated', 3)
ATF4_polysome_stressed = Data_processing.polysome_profiling_analysis(polysome_profile_data, 'ATF4','Treated', 3)
print('Untreated dataframe:')
print(ATF4_polysome_untreated)
print('Treated dataframe:')
print(ATF4_polysome_stressed)
# Out:
# Untreated dataframe:
#     Percent in fraction R1  Percent in fraction R2  Percent in fraction R3  \
# 0                 0.036116                0.153886                0.171569
# 1                 0.044938                0.324045                1.135133
# 2                 2.036976                8.203659                4.901403
# 3                 2.794833                7.306941                0.359782
# 4                12.835747                0.005582                6.533524
# 5                11.509570                3.036201                7.807504
# 6                 1.123574               22.579383               14.868578
# 7                20.679013               26.783405               24.638823
# 8                30.840667                2.551362               23.488154
# 9                12.151777               18.276706               13.160978
# 10                2.987134                6.426059                1.007324
# ...

# %%
#Plot polysome profiles
print('Untreated:')
a = Plotting.plot_gene_fractions(ATF4_polysome_untreated, 'ATF4')
Plotting.save_plot(a,Plotting.get_save_path())
# Out:
# Untreated:

# %%
b = Plotting.plot_gene_fractions(ATF4_polysome_stressed, 'ATF4')
Plotting.save_plot(b,Plotting.get_save_path())
# Out:
# Enter the path to save the plot or press enter to use the default (/default/path/plot.png):  test4.png
# Plot saved to test4.png
