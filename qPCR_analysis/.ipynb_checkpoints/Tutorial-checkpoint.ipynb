# %%
import Data_processing
import Statistics 
import Plotting 

import numpy as np 
import pandas as pd 
import scipy 
import matplotlib.pyplot as plt

# %% [markdown]
# ##Primer Efficiency tutorial##

# %%
import pandas as pd 
#Import dataset 
myData = Data_processing.import_and_tidy_data('data/dilution_testdata.csv')

#Get primer efficiency 
primer_efficiency = Data_processing.primer_efficiency(myData, 'GOI')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 9
#       6 test = Data_processing.primer_efficiency(myData, 'GOI')
#       8 plt.scatter(myData['log_dilution'], myData['Ct_value'], color='blue', label='Data')
# ----> 9 plt.plot(myData['log_dilution'], slope * myData['log_dilution'] + intercept, color='red', label='Linear regression')
#      10 plt.xlabel('log_dilution')
#      11 plt.ylabel('Ct_value')
#
# NameError: name 'slope' is not defined

# %%
Data_processing.import_and_tidy_data('data/test_data.csv')
# Out:
#        Gene  Condition  Replicate     Ct1     Ct2     Ct3   Ct_value
# 0       GOI    Treated          1  18.020  18.012  18.013  18.015000
# 1       GOI    Treated          2  16.760  16.774  16.743  16.759000
# 2       GOI    Treated          3  16.912  16.920  16.920  16.917333
# 3       GOI  Untreated          1  19.194  19.277  19.281  19.250667
# 4       GOI  Untreated          2  17.646  17.678  17.667  17.663667
# 5       GOI  Untreated          3  18.024  18.066  18.081  18.057000
# 6   Control    Treated          1  14.873  14.898  14.900  14.890333
# 7   Control    Treated          2  13.941  13.951  13.952  13.948000
# 8   Control    Treated          3  14.328  14.324  14.252  14.301333
# 9   Control  Untreated          1  14.829  14.836  14.842  14.835667
# 10  Control  Untreated          2  13.953  13.967  13.957  13.959000
# 11  Control  Untreated          3  13.934  13.927  13.939  13.933333
